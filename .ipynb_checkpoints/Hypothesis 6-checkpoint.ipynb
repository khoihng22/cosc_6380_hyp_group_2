# %% [markdown]
# ## COSC 6880 - DATA ANALYTICS
# ## Assignment 2: Hypothesis Testing
# #### Author: Khoi Nguyen
# #### Date: 02/19/2024

# %% [markdown]
# ## Hypothesis 6: In Corpus Christi, when the monthly average temperature gets higher, the monthly average wind speed will also get higher

# %% [markdown]
# - Null Hypothesis (H<sub>0</sub>): In Corpus Christi, when the monthly average temperature gets higher, the monthly average wind speed will also get higher.
# - Alternative Hypothesis (H<sub>1</sub>): In Corpus Christi, when the monthly average temperature gets higher, the monthly average wind speed will get lower or they don't have any kind of correlation at all.

# %%
import xarray as xr
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_rel
import pandas as pd
import numpy as np
from scipy import stats

# %%
corpus_christi_point_data_2000_2006 = pd.read_csv('data/corpus_christi_2000_2006.csv')

# %%
corpus_christi_point_data_2007_2024 = pd.read_csv('data/corpus_christi_2007_2024.csv')

# %%
# merge the two dataframes
corpus_christi_point_data = pd.concat([corpus_christi_point_data_2000_2006, corpus_christi_point_data_2007_2024])
corpus_christi_point_data
# Out:
#           STATION                          NAME   LATITUDE  LONGITUDE  \
# 0     USC00412011     CORPUS CHRISTI NWS, TX US  27.779300 -97.505500
# 1     USC00412011     CORPUS CHRISTI NWS, TX US  27.779300 -97.505500
# 2     USC00412011     CORPUS CHRISTI NWS, TX US  27.779300 -97.505500
# 3     USC00412011     CORPUS CHRISTI NWS, TX US  27.779300 -97.505500
# 4     USC00412011     CORPUS CHRISTI NWS, TX US  27.779300 -97.505500
# ...           ...                           ...        ...        ...
# 3148  US1TXNU0015  CORPUS CHRISTI 9.1 NW, TX US  27.802861 -97.393186
# 3149  US1TXNU0015  CORPUS CHRISTI 9.1 NW, TX US  27.802861 -97.393186
# 3150  US1TXNU0015  CORPUS CHRISTI 9.1 NW, TX US  27.802861 -97.393186
# 3151  US1TXNU0015  CORPUS CHRISTI 9.1 NW, TX US  27.802861 -97.393186
# 3152  US1TXNU0015  CORPUS CHRISTI 9.1 NW, TX US  27.802861 -97.393186
#
#       ELEVATION     DATE  AWND AWND_ATTRIBUTES   CDSD CDSD_ATTRIBUTES  ...  \
# 0          13.4  2004-10   NaN             NaN    NaN             NaN  ...
# 1          13.4  2004-11   NaN             NaN    NaN             NaN  ...
# 2          13.4  2004-12   NaN             NaN    NaN             NaN  ...
# 3          13.4  2005-01   NaN             NaN   66.0               0  ...
# 4          13.4  2005-02   NaN             NaN  134.0               0  ...
# ...         ...      ...   ...             ...    ...             ...  ...
# 3148        NaN  2023-08   NaN             NaN    NaN             NaN  ...
# 3149        NaN  2023-09   NaN             NaN    NaN             NaN  ...
# 3150        NaN  2023-10   NaN             NaN    NaN             NaN  ...
# 3151        NaN  2023-11   NaN             NaN    NaN             NaN  ...
# 3152        NaN  2024-01   NaN             NaN    NaN             NaN  ...
#
#       WDF5 WDF5_ATTRIBUTES  WDFG WDFG_ATTRIBUTES  WSF2 WSF2_ATTRIBUTES  WSF5  \
# 0      NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 1      NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 2      NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 3      NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 4      NaN             NaN   NaN             NaN   NaN             NaN   NaN
# ...    ...             ...   ...             ...   ...             ...   ...
# 3148   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 3149   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 3150   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 3151   NaN             NaN   NaN             NaN   NaN             NaN   NaN
# 3152   NaN             NaN   NaN             NaN   NaN             NaN   NaN
#
#      WSF5_ATTRIBUTES  WSFG WSFG_ATTRIBUTES
# 0                NaN   NaN             NaN
# 1                NaN   NaN             NaN
# 2                NaN   NaN             NaN
# 3                NaN   NaN             NaN
# 4                NaN   NaN             NaN
# ...              ...   ...             ...
# 3148             NaN   NaN             NaN
# 3149             NaN   NaN             NaN
# 3150             NaN   NaN             NaN
# 3151             NaN   NaN             NaN
# 3152             NaN   NaN             NaN
#
# [3398 rows x 80 columns]

# %%
corpus_christi_ws_point_data = corpus_christi_point_data.groupby('DATE')['AWND'].mean()
corpus_christi_ws_point_data = corpus_christi_ws_point_data.reset_index()

# %%
corpus_christi_temperature_point_data = corpus_christi_point_data.groupby('DATE')['TAVG'].mean()
corpus_christi_temperature_point_data = corpus_christi_temperature_point_data.reset_index()
corpus_christi_temperature_point_data
# Out:
#         DATE   TAVG
# 0    2000-01  61.55
# 1    2000-02  67.25
# 2    2000-03  71.20
# 3    2000-04  73.10
# 4    2000-05  80.35
# ..       ...    ...
# 285  2023-10  75.35
# 286  2023-11  65.26
# 287  2023-12  62.94
# 288  2024-01  55.15
# 289  2024-02    NaN
#
# [290 rows x 2 columns]

# %%
# histogram of temperature values
fig, ax = plt.subplots()
sns.histplot(corpus_christi_temperature_point_data['TAVG'], kde=True, bins=20, ax=ax)
ax.set_title('Histogram of Corpus Christi Temperature (2000-2024)')
ax.set_xlabel('Temperature (F)')
ax.set_ylabel('Frequency')
fig.show()
# Out:
# /var/folders/zq/5kj4j29n5g1_svkqqfs5bc4h0000gr/T/ipykernel_9613/1838421569.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# histogram of wind speed values
fig, ax = plt.subplots()
sns.histplot(corpus_christi_ws_point_data['AWND'], kde=True, bins=20, ax=ax)
ax.set_title('Histogram of Corpus Christi Wind Speed (2000-2024)')
ax.set_xlabel('Wind Speed (m/s)')
ax.set_ylabel('Frequency')
fig.show()
# Out:
# /var/folders/zq/5kj4j29n5g1_svkqqfs5bc4h0000gr/T/ipykernel_9613/2794649442.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# filter corpus wind speed from 2000 to 2010
corpus_christi_ws_point_data_2000_2010 = corpus_christi_ws_point_data[corpus_christi_ws_point_data['DATE'] >= '2004-01-01']
corpus_christi_ws_point_data_2000_2010 = corpus_christi_ws_point_data[corpus_christi_ws_point_data['DATE'] < '2005-01-01']
corpus_christi_ws_point_data_2000_2010

# plot histogram
fig, ax = plt.subplots()
sns.histplot(corpus_christi_ws_point_data_2000_2010['AWND'], kde=True, bins=20, ax=ax)
ax.set_title('Histogram of Corpus Christi Wind Speed (2000-2010)')
ax.set_xlabel('Wind Speed (m/s)')
ax.set_ylabel('Frequency')
fig.show()
# Out:
# /var/folders/zq/5kj4j29n5g1_svkqqfs5bc4h0000gr/T/ipykernel_9613/2572013945.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Bin the data and calculate observed frequencies
bin_edges = np.arange(0, max(corpus_christi_ws_point_data['AWND']) + 1, 2)  # Adjust binning as needed
print(len(bin_edges))
observed_freq, _ = np.histogram(corpus_christi_ws_point_data['AWND'], bins=bin_edges)
print()

# Calculate expected frequencies for a normal distribution
mean = np.mean(corpus_christi_ws_point_data['AWND'])
std = np.std(corpus_christi_ws_point_data['AWND'])
expected_freq = [len(corpus_christi_ws_point_data['AWND']) * (stats.norm.cdf(bin_edges[i+1], mean, std) - stats.norm.cdf(bin_edges[i], mean, std)) for i in range(len(bin_edges)-1)]

# Adjust expected frequencies to ensure the sum matches the sum of the observed frequencies
expected_freq = np.array(expected_freq)
expected_freq *= sum(observed_freq) / sum(expected_freq)

# Perform the Chi-square test
chi_square_stat, p_value = stats.chisquare(observed_freq, expected_freq)

print(f"Chi-square statistic: {chi_square_stat}, p-value: {p_value}")
# Out:
# 9
#
# Chi-square statistic: 4.101718827383471, p-value: 0.7679897056239826

# %%
# for the time when the mean wind speed is nan, remove the record and the correspond precipitation record and the opposite
corpus_christi_ws_point_data = corpus_christi_ws_point_data.dropna()
corpus_christi_temperature_point_data = corpus_christi_temperature_point_data[corpus_christi_temperature_point_data['DATE'].isin(corpus_christi_ws_point_data['DATE'])]

# %%
# for the time when the mean wind speed is nan, remove the record and the correspond precipitation record and the opposite
corpus_christi_temperature_point_data = corpus_christi_temperature_point_data.dropna()
corpus_christi_ws_point_data = corpus_christi_ws_point_data[corpus_christi_ws_point_data['DATE'].isin(corpus_christi_temperature_point_data['DATE'])]

# %%
# plot the scatter plot of temperature and wind speed
fig, ax = plt.subplots()
sns.scatterplot(data=corpus_christi_temperature_point_data, x='TAVG', y=corpus_christi_ws_point_data['AWND'], ax=ax)
# add a trend line
sns.regplot(data=corpus_christi_temperature_point_data, x='TAVG', y=corpus_christi_ws_point_data['AWND'], scatter=False, ax=ax)
ax.set_title('Scatter plot of Corpus Christi Temperature and Wind Speed (2000-2024)')
ax.set_xlabel('Temperature (F)')
ax.set_ylabel('Wind Speed (m/s)')
fig.show()
# Out:
# /var/folders/zq/5kj4j29n5g1_svkqqfs5bc4h0000gr/T/ipykernel_9613/2688115872.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# heat map to show the correlation between temperature and wind speed
corpus_christi_temperature_ws_point_data = pd.merge(corpus_christi_temperature_point_data, corpus_christi_ws_point_data, on='DATE')
corpus_christi_temperature_ws_point_data = corpus_christi_temperature_ws_point_data.drop(columns='DATE')

fig, ax = plt.subplots()
sns.heatmap(corpus_christi_temperature_ws_point_data.corr(), annot=True, ax=ax)
ax.set_title('Correlation between Corpus Christi Temperature and Wind Speed (2000-2024)')
fig.show()
# Out:
# /var/folders/zq/5kj4j29n5g1_svkqqfs5bc4h0000gr/T/ipykernel_9613/3151983702.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Calculate Pearson correlation coefficient
correlation_coef, p_value = stats.pearsonr(corpus_christi_temperature_point_data['TAVG'], corpus_christi_ws_point_data['AWND'])

print(f"Pearson Correlation Coefficient: {correlation_coef}, p-value: {p_value}")
# Out:
# Pearson Correlation Coefficient: -0.25892491842003645, p-value: 8.23739601647415e-06

# %%
# Perform Spearman's Rank Correlation
corr, p_value = stats.spearmanr(corpus_christi_temperature_point_data['TAVG'], corpus_christi_ws_point_data['AWND'])

# Print the results
print(f'Spearman correlation coefficient: {corr}')
print(f'P-value: {p_value}')
# Out:
# Spearman correlation coefficient: -0.30046140841110586
# P-value: 1.924334517871495e-07

# %% [markdown]
# the p-value is 0.0000082374, which is smaller than 0.5 so the Average temperature and the average wind speed were not correlated at all.
